# %% [markdown]
# # MODELIZACIÓN PARA REGRESIÓN
#
# Para este enfoque de Modelización Masiva, no queremos lograr el modelo definitivo que vamos a usar, sino que
# queremos definir el **proceso** (que ejecute bien y no de errores y que arroje datos de predicción coherentes).

# %% [markdown]
# ## IMPORTAR PAQUETES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import TimeSeriesSplit

from sklearn.ensemble import HistGradientBoostingRegressor

from sklearn.pipeline import Pipeline

from sklearn.model_selection import RandomizedSearchCV

from sklearn.metrics import mean_absolute_error

#Autocompletar rápido
# %config IPCompleter.greedy=True

#Desactivar la notación científica
pd.options.display.float_format = '{:.2f}'.format

#Desactivar los warnings
import warnings
warnings.filterwarnings("ignore")

import pickle

# %% [markdown]
# ## IMPORTAR LOS DATOS

# %% [markdown]
# Sustituir la ruta del proyecto.

# %%
ruta_proyecto = 'C:/Usuarios/Alfredo/DS4B/Python DS Mastery/EstructuraDirectorio/03_MACHINE_LEARNING/07_CASOS/02_RETAIL'

# %% [markdown]
# Nombres de los ficheros de datos.

# %%
nombre_x = 'x_preseleccionado.pickle'
nombre_y = 'y_preseleccionado.pickle'

# %% [markdown]
# Cargar los datos.

# %%
x = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_x)
y = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_y)

# %% [markdown]
# ## MODELIZANDO PARA UN PRODUCTO
#
# Elijo uno en forma arbitraria

# %%
x = x.loc[(x.store_id == 'CA_3') & (x.item_id == 'FOODS_3_586')]

# %%
x
# Out:
#            date store_id      item_id  ventas_mm_7  ventas_mm_8  ventas_mm_6  \
# 7343 2013-01-16     CA_3  FOODS_3_586         9.14         9.12         9.33
# 7344 2013-01-17     CA_3  FOODS_3_586         8.86         8.75         8.17
# 7345 2013-01-18     CA_3  FOODS_3_586         8.86         9.38         9.17
# 7346 2013-01-19     CA_3  FOODS_3_586         9.00         8.75         8.67
# 7347 2013-01-20     CA_3  FOODS_3_586         9.29         9.50        10.50
# ...         ...      ...          ...          ...          ...          ...
# 8387 2015-11-26     CA_3  FOODS_3_586         7.00         7.38         6.83
# 8388 2015-11-27     CA_3  FOODS_3_586         7.86         7.88         8.50
# 8389 2015-11-28     CA_3  FOODS_3_586         8.71         8.12         8.50
# 8390 2015-11-29     CA_3  FOODS_3_586         8.14         8.38         8.00
# 8391 2015-11-30     CA_3  FOODS_3_586         7.86         8.00         7.83
#
#       ventas_mm_9  ventas_mm_2  ventas_mm_10  ventas_mm_3  ...  \
# 7343         9.33        11.50          9.10         8.33  ...
# 7344         8.78         9.00          9.00         9.67  ...
# 7345         9.22         9.50          9.20        10.33  ...
# 7346         9.22        10.50          9.10         9.00  ...
# 7347         9.22        10.50          9.60        11.33  ...
# ...           ...          ...           ...          ...  ...
# 8387         7.11         5.00          7.10         6.00  ...
# 8388         8.11         9.50          7.80         8.00  ...
# 8389         8.11        12.00          8.30         9.67  ...
# 8390         7.89         8.00          7.90        10.00  ...
# 8391         8.22         6.50          7.80         7.67  ...
#
#       sell_price_lag_7  sell_price_lag_6  rotura_stock_3_lag_1  \
# 7343              1.48              1.48                  0.00
# 7344              1.48              1.48                  0.00
# 7345              1.48              1.48                  0.00
# 7346              1.48              1.48                  0.00
# 7347              1.48              1.48                  0.00
# ...                ...               ...                   ...
# 8387              1.58              1.58                  0.00
# 8388              1.58              1.58                  0.00
# 8389              1.58              1.58                  0.00
# 8390              1.58              1.58                  0.00
# 8391              1.58              1.58                  0.00
#
#       rotura_stock_7_lag_1  rotura_stock_15_lag_1  weekday_Sunday  wday_te  \
# 7343                  0.00                   0.00            0.00    24.89
# 7344                  0.00                   0.00            0.00    26.10
# 7345                  0.00                   0.00            0.00    29.48
# 7346                  0.00                   0.00            0.00    34.80
# 7347                  0.00                   0.00            1.00    34.39
# ...                    ...                    ...             ...      ...
# 8387                  0.00                   0.00            0.00    26.10
# 8388                  0.00                   0.00            0.00    29.48
# 8389                  0.00                   0.00            0.00    34.80
# 8390                  0.00                   0.00            1.00    34.39
# 8391                  0.00                   0.00            0.00    27.07
#
#       event_name_1_Christmas  event_name_1_Chanukah End  year_te
# 7343                    0.00                       0.00    29.95
# 7344                    0.00                       0.00    29.95
# 7345                    0.00                       0.00    29.95
# 7346                    0.00                       0.00    29.95
# 7347                    0.00                       0.00    29.95
# ...                      ...                        ...      ...
# 8387                    0.00                       0.00    28.16
# 8388                    0.00                       0.00    28.16
# 8389                    0.00                       0.00    28.16
# 8390                    0.00                       0.00    28.16
# 8391                    0.00                       0.00    28.16
#
# [1049 rows x 75 columns]

# %%
y = y[y.index.isin(x.index)]

# %% [markdown]
# ### MODELIZAR

# %% [markdown]
# #### Definir las variables de modelización
#
# Las primeras 3 no me interesan para la modelización

# %%
var_modelizar = x.columns.to_list()[3:]

# %% [markdown]
# #### Definir la validacion
#
# Recordar que para problemas de Forecasting tengo que usar TimeSeriesSplit para la CV

# %%
time_cv = TimeSeriesSplit(3, test_size = 8)  #3 combinaciones diferentes con 8 días para la validación
                                             # dado que en el modelo final quiero predecir hasta 8 días vista

# %% [markdown]
# #### Crear el pipe y el diccionario de algorimos, parámetros y valores a testar

# %% [markdown]
# Modificar para dejar solo los algoritmos que se quieran testar.
#
# Modificar los parámetros.

# %%
pipe = Pipeline([('algoritmo',HistGradientBoostingRegressor())])

grid = [   {'algoritmo': [HistGradientBoostingRegressor()],
          'algoritmo__learning_rate': [0.01,0.025,0.05,0.1],
          'algoritmo__max_iter': [50,100,200],
          'algoritmo__max_depth': [5,10,20],
          'algoritmo__min_samples_leaf': [500],
          'algoritmo__scoring': ['neg_mean_absolute_error'],
          'algoritmo__l2_regularization': [0,0.25,0.5,0.75,1]
           }
       ]

# %% [markdown]
# #### Optimizar los hiper parámetros

# %% [markdown]
# #####  Con random search

# %%
random_search = RandomizedSearchCV(estimator = pipe,
                                   param_distributions = grid, 
                                   n_iter = 5, #pruebo 5 combinaciones 
                                   cv = time_cv, 
                                   scoring = 'neg_mean_absolute_error', 
                                   verbose = 0,
                                   n_jobs = -1)

modelo = random_search.fit(x[var_modelizar],y)

pd.DataFrame(random_search.cv_results_).sort_values(by = 'rank_test_score')
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 2           0.26          0.02             0.00            0.00
# 0           0.11          0.01             0.01            0.01
# 4           0.08          0.01             0.01            0.00
# 3           0.12          0.00             0.01            0.01
# 1           0.11          0.00             0.01            0.00
#
#   param_algoritmo__scoring param_algoritmo__min_samples_leaf  \
# 2  neg_mean_absolute_error                               500
# 0  neg_mean_absolute_error                               500
# 4  neg_mean_absolute_error                               500
# 3  neg_mean_absolute_error                               500
# 1  neg_mean_absolute_error                               500
#
#   param_algoritmo__max_iter param_algoritmo__max_depth  \
# 2                       200                         10
# 0                        50                          5
# 4                        50                         10
# 3                       100                         20
# 1                        50                         20
#
#   param_algoritmo__learning_rate param_algoritmo__l2_regularization  \
# 2                           0.05                                  0
# 0                           0.10                               0.75
# 4                           0.05                               0.50
# 3                           0.01                               0.50
# 1                           0.01                               0.50
#
#                                      param_algoritmo  \
# 2  HistGradientBoostingRegressor(l2_regularizatio...
# 0  HistGradientBoostingRegressor(l2_regularizatio...
# 4  HistGradientBoostingRegressor(l2_regularizatio...
# 3  HistGradientBoostingRegressor(l2_regularizatio...
# 1  HistGradientBoostingRegressor(l2_regularizatio...
#
#                                               params  split0_test_score  \
# 2  {'algoritmo__scoring': 'neg_mean_absolute_erro...              -3.98
# 0  {'algoritmo__scoring': 'neg_mean_absolute_erro...              -4.03
# 4  {'algoritmo__scoring': 'neg_mean_absolute_erro...              -4.56
# 3  {'algoritmo__scoring': 'neg_mean_absolute_erro...              -5.60
# 1  {'algoritmo__scoring': 'neg_mean_absolute_erro...              -6.21
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 2              -2.08              -3.30            -3.12            0.79
# 0              -2.09              -3.32            -3.15            0.80
# 4              -2.43              -3.71            -3.57            0.88
# 3              -3.74              -4.68            -4.67            0.76
# 1              -4.56              -5.27            -5.35            0.68
#
#    rank_test_score
# 2                1
# 0                2
# 4                3
# 3                4
# 1                5

# %%
modelo.best_estimator_
# Out:
# Pipeline(steps=[('algoritmo',
#                  HistGradientBoostingRegressor(l2_regularization=0,
#                                                learning_rate=0.05, max_depth=10,
#                                                max_iter=200,
#                                                min_samples_leaf=500,
#                                                scoring='neg_mean_absolute_error'))])

# %%
modelo_final = modelo.best_estimator_.fit(x[var_modelizar],y)

# %% [markdown]
# Ahora hago la predicción, para ver si da algo coherente. Técnicamente no es correcto dado que estoy haciendo la predicción a partir de los datos de entrenamiento y no los de test.

# %%
prediccion = modelo_final.predict(x[var_modelizar])

# %%
temp = pd.concat([x.date.reset_index(drop=True),y.reset_index(drop=True),pd.Series(prediccion,name = 'prediccion')],axis = 1).set_index('date')

# %%
temp
# Out:
#             ventas  prediccion
# date
# 2013-01-16       6        9.93
# 2013-01-17      13        8.82
# 2013-01-18       8        8.82
# 2013-01-19      13        8.82
# 2013-01-20      13        8.82
# ...            ...         ...
# 2015-11-26      14        8.82
# 2015-11-27      10        8.82
# 2015-11-28       6        9.93
# 2015-11-29       7        8.82
# 2015-11-30       3        8.82
#
# [1049 rows x 2 columns]

# %%
temp.tail(100).plot(figsize = (16,10));

# %% [markdown]
# Da bastante mal la predicción. Pruebo con la parametrización del LightGBM por defecto.

# %%
modelo_final = HistGradientBoostingRegressor(min_samples_leaf=20).fit(x[var_modelizar],y)

# %%
prediccion = modelo_final.predict(x[var_modelizar])

# %%
temp = pd.concat([x.date.reset_index(drop=True),y.reset_index(drop=True),pd.Series(prediccion,name = 'prediccion')],axis = 1).set_index('date')

# %%
temp
# Out:
#             ventas  prediccion
# date
# 2013-01-16       6        6.49
# 2013-01-17      13       11.28
# 2013-01-18       8       10.21
# 2013-01-19      13       12.51
# 2013-01-20      13       12.02
# ...            ...         ...
# 2015-11-26      14       11.86
# 2015-11-27      10        9.94
# 2015-11-28       6        7.56
# 2015-11-29       7        7.17
# 2015-11-30       3        5.61
#
# [1049 rows x 2 columns]

# %%
temp.tail(100).plot(figsize = (16,10));

# %% [markdown]
# Me quedo con este modelo

# %% [markdown]
# ## ESCALAR A TODOS LOS PRODUCTOS

# %% [markdown]
# ### MODELIZACIÓN

# %% [markdown]
# Ya tenemos el proceso funcionando para modelizar un producto.
#
# Ahora tenemos que escalarlo a todas las combinaciones de tiendas y productos.
#
# Primero vamos a volver a importar los datos.
#
# Nota: acá vamos a suponer que todos los productos cuentan con las mismas variables pre-seleccionadas, lo cual no es correcto.
# Esto es solo para ver si está funcionando ok

# %%
nombre_x = 'x_preseleccionado.pickle'
nombre_y = 'y_preseleccionado.pickle'

# %%
x = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_x)
y = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_y)

# %% [markdown]
# Incluímos como una nueva variable "producto" en la posición 0, la combinación de tienda-producto y eliminamos las originales.

# %%
x.insert(loc=0,column='producto',value=x.store_id + '_'+ x.item_id)
x = x.drop(columns = ['store_id','item_id'])

# %% [markdown]
# Para poder aplicar el proceso de forma recurrente vamos a crear una lista donde cada elemento de la lista será una tupla, donde el primer valor es el producto y el segundo son todos los datos de ese producto (dataframe).

# %%
productos = list(x.groupby("producto"))

# %%
productos[0]
# Out:
# ('CA_3_FOODS_3_090',
#                producto       date  ventas_mm_7  ventas_mm_8  ventas_mm_6  \
#  0     CA_3_FOODS_3_090 2013-01-16       236.00       233.38       242.50
#  1     CA_3_FOODS_3_090 2013-01-17       235.14       230.38       233.50
#  2     CA_3_FOODS_3_090 2013-01-18       224.43       227.00       226.17
#  3     CA_3_FOODS_3_090 2013-01-19       225.86       224.38       205.00
#  4     CA_3_FOODS_3_090 2013-01-20       227.43       242.88       218.50
#  ...                ...        ...          ...          ...          ...
#  1044  CA_3_FOODS_3_090 2015-11-26       139.43       134.50       151.50
#  1045  CA_3_FOODS_3_090 2015-11-27       166.43       154.00       172.67
#  1046  CA_3_FOODS_3_090 2015-11-28       157.71       154.12       160.67
#  1047  CA_3_FOODS_3_090 2015-11-29       150.43       149.12       156.83
#  1048  CA_3_FOODS_3_090 2015-11-30       143.29       139.38       151.33
#
#        ventas_mm_9  ventas_mm_2  ventas_mm_10  ventas_mm_3  ventas_mm_5  ...  \
#  0          228.33       182.00        232.50       215.00       242.00  ...
#  1          228.67       174.50        224.60       185.00       237.40  ...
#  2          223.67       180.50        222.80       173.00       201.20  ...
#  3          226.67       197.00        223.70       195.00       189.80  ...
#  4          239.67       293.00        240.20       252.00       221.00  ...
#  ...           ...          ...           ...          ...          ...  ...
#  1044       126.11       216.50        122.90       176.00       156.00  ...
#  1045       148.00       289.50        139.10       229.67       179.20  ...
#  1046       144.44       162.00        140.00       215.67       170.40  ...
#  1047       146.89        78.50        138.90       137.67       169.20  ...
#  1048       139.44        75.50        138.40        73.00       159.60  ...
#
#        sell_price_lag_7  sell_price_lag_6  rotura_stock_3_lag_1  \
#  0                 1.25              1.25                  0.00
#  1                 1.25              1.25                  0.00
#  2                 1.25              1.25                  0.00
#  3                 1.25              1.25                  0.00
#  4                 1.25              1.25                  0.00
#  ...                ...               ...                   ...
#  1044              1.50              1.50                  0.00
#  1045              1.50              1.50                  0.00
#  1046              1.50              1.50                  0.00
#  1047              1.50              1.50                  0.00
#  1048              1.50              1.50                  0.00
#
#        rotura_stock_7_lag_1  rotura_stock_15_lag_1  weekday_Sunday  wday_te  \
#  0                     0.00                   0.00            0.00    24.89
#  1                     0.00                   0.00            0.00    26.10
#  2                     0.00                   0.00            0.00    29.48
#  3                     0.00                   0.00            0.00    34.80
#  4                     0.00                   0.00            1.00    34.39
#  ...                    ...                    ...             ...      ...
#  1044                  0.00                   0.00            0.00    26.10
#  1045                  0.00                   0.00            0.00    29.48
#  1046                  0.00                   0.00            0.00    34.80
#  1047                  0.00                   0.00            1.00    34.39
#  1048                  0.00                   0.00            0.00    27.07
#
#        event_name_1_Christmas  event_name_1_Chanukah End  year_te
#  0                       0.00                       0.00    29.95
#  1                       0.00                       0.00    29.95
#  2                       0.00                       0.00    29.95
#  3                       0.00                       0.00    29.95
#  4                       0.00                       0.00    29.95
#  ...                      ...                        ...      ...
#  1044                    0.00                       0.00    28.16
#  1045                    0.00                       0.00    28.16
#  1046                    0.00                       0.00    28.16
#  1047                    0.00                       0.00    28.16
#  1048                    0.00                       0.00    28.16
#
#  [1049 rows x 74 columns])

# %% [markdown]
# Encapsulamos el proceso de modelización individual en una función, a la que iremos llamando en cada producto.

# %%
#Recibe los datos de las x y la y de cada producto

def modelizar(x_producto, y):
          
    #Excluye el producto como variable de modelización
    var_modelizar = x_producto.columns.to_list()[2:]
    
    #Define la validación cruzada
    time_cv = TimeSeriesSplit(3, test_size = 8)
    
    #Define la parrilla de algoritmos
    pipe = Pipeline([('algoritmo',HistGradientBoostingRegressor())])
    grid = [ 
         {'algoritmo': [HistGradientBoostingRegressor()]
#          'algoritmo__learning_rate': [0.01,0.025,0.05,0.1],
#          'algoritmo__max_iter': [50,100,200],
#          'algoritmo__max_depth': [5,10,20,50],
#          'algoritmo__scoring': ['neg_mean_absolute_error'],
#          'algoritmo__l2_regularization': [0,0.25,0.5,0.75,1]
         }
                       
    ]
           
    #Crea los modelos
    random_search = RandomizedSearchCV(estimator = pipe,
                                   param_distributions = grid, 
                                   n_iter = 1, #toma los valores por defecto (hace solo una iteración)
                                   cv = time_cv, 
                                   scoring = 'neg_mean_absolute_error', 
                                   verbose = 0,
                                   n_jobs = -1)
    
    modelo = random_search.fit(x_producto[var_modelizar],y)
    
    #Reentrena el mejor sobre todos los datos
    modelo_final = modelo.best_estimator_.fit(x_producto[var_modelizar],y)
    
    #Devuelve como salida el modelo final
    return(modelo_final)

# %% [markdown]
# Creamos otra lista vacía donde vamos a ir guardando los modelos entrenados de cada producto.

# %%
lista_modelos = []

# %% [markdown]
# Recorremos cada elemento de la lista de productos y vamos rellendando lista_modelos con el nombre y modelo final de cada producto.

# %%
for cada in productos:
    #Renombra por claridad
    producto = cada[0] # primer elemento de la tupla: producto
    datos = cada[1]    # segundo elemento de la tupla: datos
    #Selecciona solo los datos de la target que se corresponden con el producto
    y_cada = y[y.index.isin(datos.index)]

    #Llama a la funcion de modelizar
    modelo = modelizar(datos,y_cada)
    #Añade el modelo final a la lista
    lista_modelos.append((producto,modelo))

# %%
lista_modelos
# Out:
# [('CA_3_FOODS_3_090',
#   Pipeline(steps=[('algoritmo', HistGradientBoostingRegressor())])),
#  ('CA_3_FOODS_3_120',
#   Pipeline(steps=[('algoritmo', HistGradientBoostingRegressor())])),
#  ('CA_3_FOODS_3_202',
#   Pipeline(steps=[('algoritmo', HistGradientBoostingRegressor())])),
#  ('CA_3_FOODS_3_252',
#   Pipeline(steps=[('algoritmo', HistGradientBoostingRegressor())])),
#  ('CA_3_FOODS_3_288',
#   Pipeline(steps=[('algoritmo', HistGradientBoostingRegressor())])),
#  ('CA_3_FOODS_3_329',
#   Pipeline(steps=[('algoritmo', HistGradientBoostingRegressor())])),
#  ('CA_3_FOODS_3_555',
#   Pipeline(steps=[('algoritmo', HistGradientBoostingRegressor())])),
#  ('CA_3_FOODS_3_586',
#   Pipeline(steps=[('algoritmo', HistGradientBoostingRegressor())])),
#  ('CA_3_FOODS_3_587',
#   Pipeline(steps=[('algoritmo', HistGradientBoostingRegressor())])),
#  ('CA_3_FOODS_3_714',
#   Pipeline(steps=[('algoritmo', HistGradientBoostingRegressor())])),
#  ('CA_4_FOODS_3_090',
#   Pipeline(steps=[('algoritmo', HistGradientBoostingRegressor())])),
#  ('CA_4_FOODS_3_120',
#   Pipeline(steps=[('algoritmo', HistGradientBoostingRegressor())])),
#  ('CA_4_FOODS_3_202',
#   Pipeline(steps=[('algoritmo', HistGradientBoostingRegressor())])),
#  ('CA_4_FOODS_3_252',
#   Pipeline(steps=[('algoritmo', HistGradientBoostingRegressor())])),
#  ('CA_4_FOODS_3_288',
#   Pipeline(steps=[('algoritmo', HistGradientBoostingRegressor())])),
#  ('CA_4_FOODS_3_329',
#   Pipeline(steps=[('algoritmo', HistGradientBoostingRegressor())])),
#  ('CA_4_FOODS_3_555',
#   Pipeline(steps=[('algoritmo', HistGradientBoostingRegressor())])),
#  ('CA_4_FOODS_3_586',
#   Pipeline(steps=[('algoritmo', HistGradientBoostingRegressor())])),
#  ('CA_4_FOODS_3_587',
#   Pipeline(steps=[('algoritmo', HistGradientBoostingRegressor())])),
#  ('CA_4_FOODS_3_714',
#   Pipeline(steps=[('algoritmo', HistGradientBoostingRegressor())]))]

# %% [markdown]
# Comprobamos.
#
# NOTA: El objetivo aquí no es evaluar la calidad del modelo, ya que no estamos usando los datos de entrenamiento.
#
# Es simplemente comprobar que el proceso funciona bien y no vemos nada raro antes de continuar.

# %%
# muestra las variables que uso el modelo para el primer producto
lista_modelos[0][1][0].feature_names_in_
# Out:
# array(['ventas_mm_7', 'ventas_mm_8', 'ventas_mm_6', 'ventas_mm_9',
#        'ventas_mm_2', 'ventas_mm_10', 'ventas_mm_3', 'ventas_mm_5',
#        'ventas_mm_4', 'ventas_maxm_7', 'ventas_maxm_8', 'ventas_lag_1',
#        'ventas_mm_15', 'ventas_maxm_2', 'ventas_mm_11', 'ventas_mm_13',
#        'ventas_maxm_6', 'ventas_mm_12', 'ventas_mm_14', 'ventas_maxm_9',
#        'ventas_maxm_10', 'ventas_maxm_3', 'ventas_maxm_4',
#        'ventas_maxm_5', 'ventas_maxm_13', 'ventas_maxm_11',
#        'ventas_minm_2', 'ventas_maxm_14', 'ventas_maxm_15',
#        'ventas_maxm_12', 'ventas_minm_3', 'ventas_minm_4',
#        'ventas_minm_5', 'ventas_minm_7', 'ventas_minm_6', 'ventas_minm_8',
#        'ventas_lag_2', 'ventas_lag_7', 'ventas_minm_9', 'ventas_lag_6',
#        'ventas_minm_10', 'ventas_minm_11', 'ventas_minm_12',
#        'ventas_lag_3', 'ventas_lag_8', 'ventas_minm_13', 'ventas_lag_4',
#        'ventas_lag_5', 'ventas_minm_14', 'ventas_minm_15',
#        'ventas_lag_14', 'ventas_lag_13', 'ventas_lag_9', 'ventas_lag_15',
#        'ventas_lag_12', 'ventas_lag_10', 'ventas_lag_11',
#        'sell_price_lag_2', 'sell_price_lag_4', 'sell_price_lag_3',
#        'sell_price_lag_1', 'sell_price_lag_5', 'sell_price_lag_7',
#        'sell_price_lag_6', 'rotura_stock_3_lag_1', 'rotura_stock_7_lag_1',
#        'rotura_stock_15_lag_1', 'weekday_Sunday', 'wday_te',
#        'event_name_1_Christmas', 'event_name_1_Chanukah End', 'year_te'],
#       dtype=object)

# %%
#unificar el df para poder extraer los x e y de cada producto
df =  pd.concat([x,y],axis=1)

for cada in range(0,len(lista_modelos)):
    
    #Prepara los datos necesarios
    producto = lista_modelos[cada][0]
    modelo = lista_modelos[cada][1]
    variables = modelo[0].feature_names_in_  # esto es para saber cuales fueron las variables preseleccionadas
                                             # usada por cada modelo (puede variar de un producto a otro)
    target = 'ventas'

    x_prod = df.loc[df.producto == producto].drop(columns=target).copy()
    y_prod = df.loc[df.producto == producto,'ventas'].copy()

    date = x_prod.date.values
    
    #Genera graficos de predicho vs real
    predicciones = pd.DataFrame(data={'date': date,
                                      'producto': producto,
                                      'ventas': y_prod,
                                      # para la prediccion le tengo que pasar los datos de las variables 
                                      # preseleccionadas
                                      'prediccion': modelo.predict(x_prod[variables])}) 

    predicciones['prediccion'] = predicciones.prediccion.astype('int')
    predicciones.set_index('date',inplace=True)

    predicciones.tail(100).plot(figsize = (16,8),title = producto);
